# %%
import psalm_scraper as ps
import psalm_utils as pu

# %% [markdown]
# ## Create and save a dict of psalm verses

# %%
ps_dict = ps.create_ps_dict_verses(1, 150, verbose=True)

# %%
pu.add_sentiment_scores(ps_dict)

# %%
ps.save_ps_dict(ps_dict, filename='ps_verses.json')
